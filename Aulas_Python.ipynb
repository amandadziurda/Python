# %% [markdown]
# <a href="https://colab.research.google.com/github/amandadziurda/Python/blob/main/Aulas_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **AULA 1**

# %%
print(f"{ano} competição de programação da Start")
# Out:
# II competição de programação da Start

# %%
print(ano, "competição de programação da Start")
# Out:
# II competição de programação da Start

# %%
ano = "VI"

# %%
print("I competição de programação dá Start")
# Out:
# I competição de programação dá Start

# %% [markdown]
# **AULA 2**

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
pontos_ana = livro_ficcao * 2 + livro_infantil * 5
print(f"Os pontos totais de Ana são {pontos_ana}")
pontos_carlos = livro_ficcao * 1 + livro_n_ficcao * 3 + livro_infantil * 3
print(f"Os pontos totais do Carlos são {pontos_carlos}")
pontos_totais = pontos_rodrigo + pontos_ana + pontos_carlos
print(f"O total de pontos de Rodrigo, Ana e Carlos juntos é {pontos_totais}")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais de Ana são 46
# Os pontos totais do Carlos são 56
# O total de pontos de Rodrigo, Ana e Carlos juntos é 126

# %%
total_de_figurinhas = int(input("Digite o total de figurinhas: "))
numero_de_amigos = int(input("Digite o total de amigos: "))
figurinhas_amigo = total_de_figurinhas // (numero_de_amigos + 2)
figurinhas_joao = 2 * figurinhas_amigo

print(f"João recebeu {figurinhas_joao} figurinhas")

# %% [markdown]
# **AULA 3**

# %%
numero_de_alunos = int(input("Digite a quantidade de alunos: "))
numero_de_monitores = int(input("Digite a quantidade de monitores: "))
if numero_de_alunos + numero_de_monitores <= 50:
  resposta_positiva = "pode ir"
  resposta_negativa = "não pode ir"
if numero_de_alunos + numero_de_monitores <= 50:
  print(resposta_positiva)
else:
  print(resposta_negativa)
# Out:
# Digite a quantidade de alunos: 6
# Digite a quantidade de monitores: 6
# pode ir

# %%
quantidade_professores = 8
numero_de_alunos = int(input("Digite a quantidade de alunos: "))
numero_de_monitores = int(input("Digite a quantidade de monitores: "))
if numero_de_alunos + numero_de_monitores <= 30:
  resposta_positiva = "pode ir"
  resposta_negativa = "não pode ir"
if numero_de_alunos + numero_de_monitores + quantidade_professores <= 30:
  print(resposta_positiva)
else:
  print(resposta_negativa)
# Out:
# Digite a quantidade de alunos: 15
# Digite a quantidade de monitores: 8
# não pode ir

# %% [markdown]
# **AULA 4**

# %%
P = int(input("Digite a posição da porta P (0 ou 1): "))
R = int(input("Digite a posição da porta R (0 ou 1): "))
if P == 0:
    print("C")
elif R == 1:
    print("A")
else:
    print("B")
# Out:
# Digite a posição da porta P (0 ou 1): 1
# Digite a posição da porta R (0 ou 1): 2
# B

# %%
P = int(input("Digite a posição da porta P (0 ou 1): "))
R = int(input("Digite a posição da porta R (0 ou 1): "))
Q = int(input("Digite a posição da porta Q (0 ou 1): "))
if P == 0:
    print("C")
elif R == 1:
    print("A")
else:
    print("B")
if Q == 1:
    print("D")
# Out:
# Digite a posição da porta P (0 ou 1): 1
# Digite a posição da porta R (0 ou 1): 2
# Digite a posição da porta Q (0 ou 1): 3
# B

# %% [markdown]
# **AULA 6**

# %%
def calcula_idade_maior(idade_monica, idade_filho1, idade_filho2):
  idade_filho3 = idade_monica - idade_filho1 - idade_filho2
  idade_maxima = max(idade_filho1, idade_filho2, idade_filho3)
  return idade_filho3, idade_maxima

# %% [markdown]
# **AULA 7**

# %% [markdown]
# **CRIANDO UM CHATBOT:**
#
# RECEBER PERGUNTA do aluno
#
# SE a PERGUNTA for "verificar nota"
# OBTER DADOS do Aluno (Nome e Matrícula)
# CONSULTAR SISTEMA de notas com os DADOS do Aluno

# %% [markdown]
# 🥰⭐✨ **AULA 8** ✨⭐🥰

# %%
print ("Sou seu assistente virtual, \n")
nome =  input ("Digite o seu nome:")
print (f"Olá, {nome}. Qual é a sua dúvida hoje?")
resposta = input("Qual assunto deseja tratar: Matemática, Python, JavaScript").lower()
print(f"Que bom, {nome}, vamos falar sobre {resposta}")
if resposta== "python":
  print ("💻📒 Ótimo, vamos falar sobre Python! Python se destaca na computação científica, análise de dados e machine learning, oferecendo bibliotecas robustas como NumPy e SciPy para manipulação de vetores, matrizes e algoritmos complexos. Sua sintaxe clara permite que cientistas de dados e pesquisadores traduzam facilmente modelos matemáticos em código funcional.")
elif resposta== "matemática":
  print ("📊📚 Perfeito, vamos ver um pouco sobre Matemática! Matemática é a ciência do raciocínio lógico e abstrato, que estuda quantidades, medidas, estruturas, variações, padrões e estatísticas. É um campo do conhecimento que utiliza conceitos e técnicas para formar conhecimentos abstratos e concretos.")
elif resposta== "javascript":
  print ("🖥📖 Que legal, vamos conversar sobre Javascript! JavaScript é uma linguagem de programação versátil e dinâmica, que atua como um dos pilares fundamentais do desenvolvimento web. Ela permite criar conteúdo que se atualiza de forma dinâmica, controla multimídia, anima imagens e, em geral, faz as páginas da web mais interativas.")
else:
         print ("Hum, não sei falar sobre esse assunto!🙁")
# Out:
# SOU SEU ASSISTENTE VIRTUAL,
#
# DIGITE O SEU NOME:amanda
# OLÁ, amanda . QUAL É A SUA DÚVIDA HOJE?
# QUAL ASSUNTO QUE DESEJA TRATAR: MATEMÁTICA , PYTHON , JAVASCRIPTphiton
# QUE BOM, amanda, VAMOS FALAR SOBRE phiton
