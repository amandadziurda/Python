# %% [markdown]
# <a href="https://colab.research.google.com/github/amandadziurda/Python/blob/main/PALAVRAS_DIFICEIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #✨ ⭐ **PALAVRAS DIFÍCEIS "SAEB"** ⭐ ✨
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  📒 ⭐ **ENUNCIADO 1** ⭐ 📒
#
# 46 - (X11011PR25) Pedro está desenvolvendo por meio da ferramenta P5.js uma programação que irá
# gerar uma animação de um campo de futebol para explicar o funcionamento de algumas regras
# desse esporte, por isso ele precisa que a bola circule de diferentes modos pela representação.
# Para isso, ele utilizará o conceito de variável por meio do comando let=
#
# **→ Palavras que podem dificultar entendimento da resolução:**
# - Ferramenta P5.js
# - Conceito de variável
# - Comando let=
#
# 📒 ⭐ **ENUNCIADO 2** ⭐ 📒
#
# 47 - (X11021PR25) Para fazer programações Javascript, a ferramenta P5.js é muito utilizada, pois
# suas funções permitem criar diferentes artes interativas, jogos e animações.
# Dentre as funções do P5.js está a line(), que tem por objetivo
#
# **→ Palavras que podem dificultar entendimento da resolução:**
# - Ferramenta P5.js
# - Funções do P5.js
# - line()
#
# 📒 ⭐ **ENUNCIADO 3** ⭐ 📒
#
# 48 - (X11031PR25) Você e seus amigos estão organizando um campeonato de videogame. Para
# incentivar a participação, decidiram premiar os jogadores com pontos extras, dependendo de
# suas colocações no ranking. Cada jogador recebe uma pontuação inicial de 100 pontos e um
# bônus, calculado com base na sua posição final.
#
# **→ Palavras que podem dificultar entendimento da resolução:**
# - let
# - posicaoMaxima
# - console.log
